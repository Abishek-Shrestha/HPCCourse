# %% [markdown]
# # This is a title
#
# This is some text
#
# *My name in italics*

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = pd.read_csv('scatter.csv')
data1.head()
# Out:
#        x       y
# 0  77.91  137.94
# 1  73.55  140.19
# 2  67.73  103.18
# 3  72.21  107.69
# 4  65.87  111.92

# %%
plt.scatter(data1.x, data1.y, c = 'blue')
plt.show()

# %%
data2 = pd.read_csv('guess1.csv')
data2.head()
# Out:
#      x      y
# 0  0.0  37.31
# 1  1.0  38.42
# 2  2.0  39.53
# 3  3.0  40.64
# 4  4.0  41.75

# %%
plt.figure(figsize=(10,8))
plt.scatter(data1.x, data1.y, c='b')
plt.plot(data2.x, data2.y, c ='red')
plt.title('Guess one')
plt.show()

# %%
data3 = pd.read_csv('guess2.csv')
data3.head()
# Out:
#      x      y
# 0  0.0  38.31
# 1  1.0  39.43
# 2  2.0  40.55
# 3  3.0  41.67
# 4  4.0  42.79

# %%
plt.figure(figsize=(10,8))
plt.scatter(data1.x, data1.y)
plt.plot(data3.x, data3.y, c='green')
plt.title('guess two')
plt.show()

# %%
data4 = pd.read_csv('guess3.csv')
data4.head()
# Out:
#      x      y
# 0  0.0  39.31
# 1  1.0  40.44
# 2  2.0  41.57
# 3  3.0  42.70
# 4  4.0  43.83

# %%
plt.figure(figsize=(10,8))
plt.scatter(data1.x, data1.y)
plt.plot(data4.x, data4.y, c='yellow')
plt.title('guess three')
plt.show()

# %%
data5 = pd.read_csv('guess4.csv')
data5.head()
# Out:
#      x      y
# 0  0.0  40.31
# 1  1.0  41.45
# 2  2.0  42.59
# 3  3.0  43.73
# 4  4.0  44.87

# %%
plt.figure(figsize=(10,8))
plt.scatter(data1.x, data1.y)
plt.plot(data5.x, data5.y, c='black')
plt.title('guess four')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(data1.x, data1.y)
plt.plot(data2.x, data2.y, c='r')
plt.plot(data3.x, data3.y, c='g')
plt.plot(data4.x, data4.y, c='yellow')
plt.plot(data5.x, data5.y, c='orange')
plt.ylabel('y-intercept')
plt.xlabel('x-intercept')
plt.legend()
plt.show()
